# %%
import torch
from calibr_polar import *
import copy

import matplotlib.pyplot as plt

# %%
device = torch.device('cpu')

# %%
#res1, res2, res3, res4, res5, res6 = extract_calibr('\\\\NAS_LOCCO\\Amaury\\data\\4polar_data_raw\\2026_01_16_calibr_polar_objectif\\Calib_Polar_2026-01-16_0\\images\\RAW_DATA\\image_Pos0.ome.tif')
res1, res2, res3, res4, res5, res6 = extract_calibr('\\\\NAS_LOCCO\\Amaury\\DATA\\4polar_data_raw\\2026_02_19_calibration\\polar\\Calib_Polar_2026-02-19_0\\images\\RAW_DATA\\image_Pos0.ome.tif')
# Out:
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')

# %%
zer = zero('\\\\NAS_LOCCO\\Amaury\\DATA\\4polar_data_raw\\2026_02_19_calibration\\polar\\Calib_Polar_2026-02-19_0\\images\\RAW_DATA\\image_Pos0.ome.tif')
# Out:
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')

# %%
intensity = open_ome('\\\\NAS_LOCCO\\Amaury\\DATA\\4polar_data_raw\\2026_02_19_calibration\\intensity\\Calib_Polar_2026-02-19\\images\\RAW_DATA\\image_Pos0.ome.tif')
# Out:
# <tifffile.read_micromanager_metadata> failed to read index map, raised ValueError('invalid header')
# <tifffile.read_micromanager_metadata> failed to read display settings, raised ValueError('invalid display_header 0')

# %%
i1, i2, i3, i4, i5, i6 = extract_sqr(intensity)

# %%
i1-=zer
i2-=zer
i3-=zer
i4-=zer
i5-=zer
i6-=zer

# %%
res1-=zer
res2-=zer
res3-=zer
res4-=zer
res5-=zer
res6-=zer

# %%
res1/=i1
res2/=i2
res3/=i3
res4/=i4
res5/=i5
res6/=i6

# %%
plt.plot(res1)
#plt.plot(res2)
plt.plot(res3)
#plt.plot(res4)
#plt.plot(res5)
#plt.plot(res6)

# %%
np.cos(75*np.pi/280)
# Out:
# 0.6663465779520039

# %%
a1 = 0.95
b1 = -0.3
b2 = 0.001
c1 = 0.3
c2 = 0.001
d1 = 0.95
d2 = 0.001

I0 = 1.
    
a1_ = 0.66
b1_ = -0.74
b2_ = 0.001
c1_ = 0.74
c2_ = 0.001
d1_ = 0.66
d2_ = 0.001

# %%
def through_microscope(I0, a1, b1, b2, c1, c2, d1, d2, a1_, b1_, b2_, c1_, c2_, d1_, d2_):
    J1 = torch.stack([
        torch.stack([a1, b1 + 1j*b2]),
        torch.stack([c1 + 1j*c2, d1 + 1j*d2])
    ]
    ).to(torch.complex128)
    J2 = torch.stack([
        torch.stack([a1_, b1_ + 1j*b2_]),
        torch.stack([c1_ + 1j*c2_, d1_ + 1j*d2_])
    ]
    ).to(torch.complex128)
    phii = (torch.linspace(np.pi/2, 1.5*np.pi, 37).to(device))[:-1]
    input_ = I0*torch.stack([torch.cos(phii), torch.sin(phii)]).to(device).to(torch.complex128)
    output_ = torch.einsum('ab,bc->ac', J1, input_)
    output_2 =  torch.einsum('ab,bc->ac', J2, input_)
    return (output_[0]*torch.conj(output_[0])).to(torch.float64), (output_[1]*torch.conj(output_[1])).to(torch.float64), (output_2[0]*torch.conj(output_2[0])).to(torch.float64), (output_2[1]*torch.conj(output_2[1])).to(torch.float64)

# %%
res1 = torch.tensor(res1, device=device)
res2 = torch.tensor(res2, device=device)
res3 = torch.tensor(res3, device=device)
res4 = torch.tensor(res4, device=device)
res5 = torch.tensor(res5, device=device)
res6 = torch.tensor(res6, device=device)
# Out:
# C:\Users\Amaury\AppData\Local\Temp\ipykernel_4216\1781850405.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   res1 = torch.tensor(res1, device=device)
# C:\Users\Amaury\AppData\Local\Temp\ipykernel_4216\1781850405.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   res2 = torch.tensor(res2, device=device)
# C:\Users\Amaury\AppData\Local\Temp\ipykernel_4216\1781850405.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   res3 = torch.tensor(res3, device=device)
# C:\Users\Amaury\AppData\Local\Temp\ipykernel_4216\1781850405.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   res4 = torch.tensor(res4, device=device)
# C:\Users\Amaury\AppData\Local\Temp\ipykernel_4216\1781850405.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   res5 = torch.tensor(res5, device=device)
# C:\Users\Amaury\AppData\Local\Temp\ipykernel_4216\1781850405.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   res6 = torch.tensor(res6, device=device)

# %%
params = torch.tensor([I0, a1, b1, b2, c1, c2, d1, d2, a1_, b1_, b2_, c1_, c2_, d1_, d2_], device=device)
params.requires_grad=True
optimizer = torch.optim.Adam([params], lr=.05)
loss_ = []

# %%
def loss_f(para):
    I0, a1, b1, b2, c1, c2, d1, d2, a1_, b1_, b2_, c1_, c2_, d1_, d2_ = para[0], para[1], para[2], para[3], para[4], para[5], para[6], para[7] , para[8], para[9], para[10], para[11], para[12] , para[13], para[14]
    th1, th2, th3, th4 = through_microscope(I0, a1, b1, b2, c1, c2, d1, d2, a1_, b1_, b2_, c1_, c2_, d1_, d2_) 
    J1 = torch.stack([
        torch.stack([a1, b1 + 1j*b2]),
        torch.stack([c1 + 1j*c2, d1 + 1j*d2])
    ]
    ).to(torch.complex128)   
    J2 = torch.stack([
        torch.stack([a1_, b1_ + 1j*b2_]),
        torch.stack([c1_ + 1j*c2_, d1_ + 1j*d2_])
    ]
    ).to(torch.complex128)   
    force_unitary1 = 5*torch.sum(torch.abs((torch.einsum('ab, bc-> ac', torch.transpose(torch.conj(J1), 0, 1), J1)-torch.ones(2))**2))
    force_unitary2 = 5*torch.sum(torch.abs((torch.einsum('ab, bc-> ac', torch.transpose(torch.conj(J2), 0, 1), J2)-torch.ones(2))**2))
    return torch.sum((th1-res1)**2)+torch.sum((th2-res2)**2) + torch.sum((th3-res3)**2)+torch.sum((th4-res4)**2) + (para[0]-torch.abs(para[0]))**2 + (para[1]-torch.abs(para[1]))**2 + (para[6]-torch.abs(para[6]))**2 + force_unitary1 + force_unitary2

# %%
for i in range(500):
    optimizer.zero_grad()
    loss=loss_f(params)
    loss.backward()  # Backpropagation
    optimizer.step()
    loss_.append(loss.cpu().detach().numpy())

# %%
plt.plot(loss_)

# %%
print('I0 = ', params[0].cpu().detach().numpy())
print('J1 = [[', params[1].cpu().detach().numpy(), '       ,            ', params[2].cpu().detach().numpy(), '+ 1j* ', params[3].cpu().detach().numpy(), '],[')
print('     ', params[4].cpu().detach().numpy(), '+ 1j* ', params[5].cpu().detach().numpy(), ' ,  ', params[6].cpu().detach().numpy(), '+ 1j* ', params[7].cpu().detach().numpy(), ']]')
print('J2 = [[', params[8].cpu().detach().numpy(), '              ,     ', params[9].cpu().detach().numpy(), '+ 1j* ', params[10].cpu().detach().numpy(), '],[')
print('     ', params[11].cpu().detach().numpy(), '+ 1j* ', params[12].cpu().detach().numpy(), '  , ', params[13].cpu().detach().numpy(), '+ 1j* ', params[14].cpu().detach().numpy(), ']]')
# Out:
# I0 =  1.5267166
# J1 = [[ 0.9333594        ,             -0.080741644 + 1j*  0.45935062 ],[
#       0.27964854 + 1j*  0.365719  ,   0.9335184 + 1j*  -0.10434684 ]]
# J2 = [[ 0.56032944               ,      -0.71155554 + 1j*  0.49166024 ],[
#       0.8587344 + 1j*  0.006273807   ,  0.6251188 + 1j*  -0.16865717 ]]

# %%
I0, a1, b1, b2, c1, c2, d1, d2, a1_, b1_, b2_, c1_, c2_, d1_, d2_, = params[0].cpu(), params[1].cpu(), params[2].cpu(), params[3].cpu(), params[4].cpu(), params[5].cpu(), params[6].cpu(), params[7].cpu() , params[8].cpu(), params[9].cpu(), params[10].cpu(), params[11].cpu(), params[12].cpu() , params[13].cpu(), params[14].cpu()
J1 = torch.stack([
        torch.stack([a1, b1 + 1j*b2]),
        torch.stack([c1 + 1j*c2, d1 + 1j*d2])
    ]
    ).to(torch.complex128)
J2 = torch.stack([
        torch.stack([a1_, b1_ + 1j*b2_]),
        torch.stack([c1_ + 1j*c2_, d1_ + 1j*d2_])
    ]
    ).to(torch.complex128)
force_unitary1 = torch.sum(torch.abs((torch.einsum('ab, bc-> ac', torch.transpose(torch.conj(J1), 0, 1), J1)-torch.ones(2))**2))
force_unitary2 = torch.sum(torch.abs((torch.einsum('ab, bc-> ac', torch.transpose(torch.conj(J2), 0, 1), J2)-torch.ones(2))**2))
print(force_unitary1, force_unitary2)
# Out:
# tensor(1.4770, dtype=torch.float64, grad_fn=<SumBackward0>) tensor(1.5521, dtype=torch.float64, grad_fn=<SumBackward0>)

# %%
predicted1, predicted2, predicted3, predicted4 = through_microscope(params[0], params[1], params[2], params[3], params[4], params[5], params[6], params[7] , params[8], params[9], params[10], params[11], params[12], params[13], params[14]) 
predicted1 = predicted1.cpu().detach().numpy()
predicted2 = predicted2.cpu().detach().numpy()
predicted3 = predicted3.cpu().detach().numpy()
predicted4 = predicted4.cpu().detach().numpy()

# %%
plt.rcParams['figure.figsize'] = [6, 4]
fig, ax = plt.subplots(2,2)
phi = (np.linspace(np.pi/2, 1.5*np.pi, 37)+params[9].detach().numpy())[:-1]
ax[0,0].plot(phi*180/np.pi, predicted1/0.04, label = 'Fit')
ax[0,0].scatter(phi*180/np.pi, res1/0.04, c='r', marker='x', s=10, label = 'Experimental data')
ax[0,0].legend()
#ax[0,0].set_ylim((0., 1))
ax[0,0].grid()
ax[0,0].set_xlabel('Polarizer angle ($\\degree$)')
ax[0,0].set_ylabel('Intensity (a.u.)')
ax[0,1].plot(phi*180/np.pi, predicted2/0.04)
ax[0,1].scatter(phi*180/np.pi, res2/0.04, c='r', marker='x', s=10)
#ax[0,1].set_ylim((0., 1))
ax[0,1].grid()
ax[0,1].set_xlabel('Polarizer angle ($\\degree$)')
ax[0,1].set_ylabel('Intensity (a.u.)')
ax[1,0].plot(phi*180/np.pi, predicted3/0.04)
ax[1,0].scatter(phi*180/np.pi, res3/0.04, c='r', marker='x', s=10)
#ax[1,0].set_ylim((0., 1))
ax[1,0].grid()
ax[1,0].set_xlabel('Polarizer angle ($\\degree$)')
ax[1,0].set_ylabel('Intensity (a.u.)')
ax[1,1].plot(phi*180/np.pi, predicted4/0.04)
ax[1,1].scatter(phi*180/np.pi, res4/0.04, c='r', marker='x', s=10)
#ax[1,1].set_ylim((0., 1))
ax[1,1].grid()
ax[1,1].set_xlabel('Polarizer angle ($\\degree$)')
ax[1,1].set_ylabel('Intensity (a.u.)')
plt.savefig("calibr.svg", format="svg")

# %%
I0 =  1.5267166
J1 = [[ 0.9333594        ,             -0.080741644 + 1j*  0.45935062 ],[
      0.27964854 + 1j*  0.365719  ,   0.9335184 + 1j*  -0.10434684 ]]
J2 = [[ 0.56032944               ,      -0.71155554 + 1j*  0.49166024 ],[
      0.8587344 + 1j*  0.006273807   ,  0.6251188 + 1j*  -0.16865717 ]]
